# %%
import pandas as pd

# %% [markdown]
# ### Fact Table

# %%
flights = pd.read_csv('data/flights.csv', dtype={'YEAR':'str', 'MONTH': 'str', 'DAY':'str'})
# Out:
# /var/folders/v7/cd7r3hf1229b9tnytv_qr8hm0000gn/T/ipykernel_75706/1234625740.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights = pd.read_csv('data/flights.csv', dtype={'YEAR':'str', 'MONTH': 'str', 'DAY':'str'})

# %%
flights.sample(5)
# Out:
#          YEAR MONTH DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 554527   2015     2   6            5      WN            889      N551WN
# 4934951  2015    11   4            3      WN           5484      N214WN
# 365304   2015     1  25            7      NK            301      N622NK
# 2020746  2015     5   9            6      DL           1444      N588NW
# 2856103  2015     6  29            1      DL            823      N938DL
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 554527             SFO                 DEN                 1350  ...
# 4934951            BWI                 BUF                 2015  ...
# 365304             BWI                 FLL                  645  ...
# 2020746            DTW                 RSW                  736  ...
# 2856103            CLT                 ATL                  540  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 554527         2029.0          189.0         0          0
# 4934951        2117.0           -8.0         0          0
# 365304          856.0          -26.0         0          0
# 2020746        1012.0          -11.0         0          0
# 2856103         634.0          -13.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 554527                   NaN              10.0             0.0           34.0
# 4934951                  NaN               NaN             NaN            NaN
# 365304                   NaN               NaN             NaN            NaN
# 2020746                  NaN               NaN             NaN            NaN
# 2856103                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 554527                 145.0            0.0
# 4934951                  NaN            NaN
# 365304                   NaN            NaN
# 2020746                  NaN            NaN
# 2856103                  NaN            NaN
#
# [5 rows x 31 columns]

# %%
flights['fullDate'] = pd.to_datetime(flights[['YEAR', 'MONTH', 'DAY']])

flights['MONTH'] = flights['MONTH'].str.zfill(2)
flights['DAY'] = flights['DAY'].str.zfill(2)

flights['dateKey'] = flights['YEAR'].astype('str') + flights['MONTH'].astype('str') + flights['DAY'].astype('str')

# %%
flights['SCHEDULED_DEPARTURE'] = flights['SCHEDULED_DEPARTURE'].astype('str').str.zfill(4)
flights['SCHEDULED_ARRIVAL'] = flights['SCHEDULED_ARRIVAL'].astype('str').str.zfill(4)

# %%
flights.rename(columns={'SCHEDULED_DEPARTURE':'scheduledDeparture_key',
                       'SCHEDULED_ARRIVAL':'scheduledArrival_key'}, inplace=True)

# %% [markdown]
# ### Date Dimenssion

# %%
date_dim = flights.loc[:,['YEAR','MONTH','DAY','DAY_OF_WEEK', 'fullDate', 'dateKey']]

# %%
date_dim.drop_duplicates(inplace=True)

# %%
flights.drop(columns=['YEAR','MONTH','DAY','DAY_OF_WEEK', 'fullDate'], inplace=True)

# %%
date_dim['month_name'] = date_dim['fullDate'].dt.month_name()
date_dim['day_name'] = date_dim['fullDate'].dt.day_name()

# %%
date_dim
# Out:
#          YEAR MONTH DAY  DAY_OF_WEEK   fullDate   dateKey month_name  \
# 0        2015    01  01            4 2015-01-01  20150101    January
# 13950    2015    01  02            5 2015-01-02  20150102    January
# 30691    2015    01  03            6 2015-01-03  20150103    January
# 46125    2015    01  04            7 2015-01-04  20150104    January
# 62477    2015    01  05            1 2015-01-05  20150105    January
# ...       ...   ...  ..          ...        ...       ...        ...
# 5740666  2015    12  27            7 2015-12-27  20151227   December
# 5757175  2015    12  28            1 2015-12-28  20151228   December
# 5773487  2015    12  29            2 2015-12-29  20151229   December
# 5789686  2015    12  30            3 2015-12-30  20151230   December
# 5805946  2015    12  31            4 2015-12-31  20151231   December
#
#           day_name
# 0         Thursday
# 13950       Friday
# 30691     Saturday
# 46125       Sunday
# 62477       Monday
# ...            ...
# 5740666     Sunday
# 5757175     Monday
# 5773487    Tuesday
# 5789686  Wednesday
# 5805946   Thursday
#
# [365 rows x 8 columns]

# %% [markdown]
# ### Time Dimenssion

# %%
departureTime_dim = pd.DataFrame(flights['scheduledDeparture_key'])
arrivalTime_dim = pd.DataFrame(flights['scheduledArrival_key'])

# %%
departureTime_dim['Hour'] = departureTime_dim['scheduledDeparture_key'].str[:2]
departureTime_dim['Minute'] = departureTime_dim['scheduledDeparture_key'].str[-2:]

arrivalTime_dim['Hour'] = arrivalTime_dim['scheduledArrival_key'].str[:2]
arrivalTime_dim['Minute'] = arrivalTime_dim['scheduledArrival_key'].str[-2:]

# %%
departureTime_dim.drop_duplicates(inplace=True)
arrivalTime_dim.drop_duplicates(inplace=True)

# %%
# departureTime_dim.rename(columns={'SCHEDULED_DEPARTURE':'timeKey'}, inplace=True)
# arrivalTime_dim.rename(columns={'SCHEDULED_ARRIVAL':'timeKey'}, inplace=True)

# %%
departureTime_dim.sample(5)
# Out:
#        scheduledDeparture_key Hour Minute
# 13801                    2254   22     54
# 668359                   2332   23     32
# 13859                    2320   23     20
# 2793                     0925   09     25
# 4184                     1059   10     59

# %% [markdown]
# ### Airport Dimenssion

# %%
airports = pd.read_csv('data/airports.csv')

# %%
departureAirport_dim = airports
arrivalAirport_dim = airports

# %% [markdown]
# #### Export Fact and Dimenssion files

# %%
# Departure and Arrival airport dimension
arrivalAirport_dim.to_csv('arrivalAirport_dim.csv', index=False)
departureAirport_dim.to_csv('departureAirport_dim.csv', index=False)

# Departure Date
date_dim.to_csv('date_dim.csv', index=False)

# Departure and arrival time dimension
arrivalTime_dim.to_csv('arrivalTime_dim.csv', index=False)
departureTime_dim.to_csv('departureTime_dim.csv', index=False)

# %%
# Fact table
flights.to_csv('flights_fact.csv', index=False)

# %% [markdown]
# ### Manipulate the Aircraft dimension

# %%
aircraft_master = pd.read_csv('data/Aircraft/MASTER.txt', usecols=['N-Number', 'AircraftMFRModelCode', 
                                                                   'TypeAcft', 'Year Mfr'])
for i in aircraft_master.columns:
    aircraft_master[i] = aircraft_master[i].astype('str').str.strip()

aircraft_master.sample(5)
# Out:
# /var/folders/v7/cd7r3hf1229b9tnytv_qr8hm0000gn/T/ipykernel_75706/2434535679.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   aircraft_master = pd.read_csv('data/Aircraft/MASTER.txt', usecols=['N-Number', 'AircraftMFRModelCode',
#        N-Number AircraftMFRModelCode Year Mfr TypeAcft
# 80687     7391J              7102802     1968        4
# 273544    835NN              13844CB     2010        5
# 25452     813JR
# 263359    2191G              1050113     2004        2
# 180399    2818R              7102811     1969        4

# %%
mfr_ref = pd.read_csv('data/Aircraft/AcftRef.txt', header=None, usecols=[0,1,2,6,7,10], skipinitialspace=True)
mfr_ref.sample(5)

for i in mfr_ref.columns:
    mfr_ref[i] = mfr_ref[i].astype('str').str.strip()
    
col_names = {
    0 : 'mfr_name',
    1 : 'model_name',
    2 : 'type',
    6 : 'num_engines',
    7 : 'num_passengers',
    10 : 'mfr_code'
}
mfr_ref.rename(columns=col_names, inplace=True)

# %%
mfr_ref.sample(5)
# Out:
#                           mfr_name model_name type num_engines num_passengers  \
# 8990   GRUMMAN AMERICAN AVN. CORP.       AA-1    4           1              2
# 16346             DECATO RICHARD L   LONG-EZE    4           1              2
# 20949               HEIDECKER JOHN  TIERRA II    4           1              2
# 75408             MCDANIEL JAMES E      SONEX    4           1              2
# 57840                        PIPER  J3C-90-8F    4           1              2
#
#       mfr_code
# 8990   3960101
# 16346  05609NP
# 20949  05675J4
# 75408  05631XR
# 57840  710052T

# %%
aircraft_info = pd.merge(aircraft_master, mfr_ref, left_on='AircraftMFRModelCode', right_on='mfr_code')
aircraft_info.drop(columns='mfr_code', inplace=True)
aircraft_info.sample(5)
# Out:
#        N-Number AircraftMFRModelCode Year Mfr TypeAcft  \
# 119195    329CJ              2076616     2007        5
# 148253    717HC              2400108     1981        4
# 276311    260KM              05633ZH     2015        4
# 197709    823UP              4220035     2014        5
# 74275      25MM              2072821     1975        4
#
#                              mfr_name           model_name type num_engines  \
# 119195                         CESSNA                 525B    5           2
# 148253  CONSOLIDATED AERONAUTICS INC.        LAKE LA-4-200    4           1
# 276311                MAYEUX SIDNEY F  VANS ACFT INC RV-7A    4           1
# 197709                BEECHCRAFT CORP                 B300    5           2
# 74275                          CESSNA                A185F    4           1
#
#        num_passengers
# 119195              8
# 148253              4
# 276311              2
# 197709             19
# 74275               6

# %%
aircraft_info['N-Number'] = "N" + aircraft_info['N-Number']

# %%
aircraft_info['mfr_name'].replace({'AIRBUS INDUSTRIE' : 'AIRBUS'}, inplace=True)

# %%
aircraft_info[aircraft_info['N-Number']=='N751SW']
# Out:
#      N-Number AircraftMFRModelCode Year Mfr TypeAcft mfr_name model_name type  \
# 8578   N751SW              1384404     1999        5   BOEING    737-7H4    5
#
#      num_engines num_passengers
# 8578           2            140

# %%
aircraft_info = aircraft_info[aircraft_info['N-Number'].isin(flights['TAIL_NUMBER'])]

# %%
aircraft_info['mfr_name'].value_counts()
# Out:
# BOEING                           2002
# AIRBUS                            974
# BOMBARDIER INC                    436
# EMBRAER                           349
# MCDONNELL DOUGLAS                 119
# MCDONNELL DOUGLAS AIRCRAFT CO     103
# EMBRAER S A                        43
# MCDONNELL DOUGLAS CORPORATION      14
# CANADAIR                           12
# CESSNA                              9
# PIPER                               6
# BEECH                               5
# GULFSTREAM AEROSPACE                4
# DIAMOND AIRCRAFT IND INC            2
# RAYTHEON AIRCRAFT COMPANY           2
# CIRRUS DESIGN CORP                  2
# BELL                                1
# DOUGLAS                             1
# BENHAM JOHN                         1
# KILDALL GARY                        1
# LAMBERT RICHARD                     1
# EXTRA FLUGZEUGBAU GMBH              1
# BARKER JACK L                       1
# PAIR MIKE E                         1
# GROSS ROBERT                        1
# SIKORSKY                            1
# ROBINSON HELICOPTER CO              1
# LEARJET INC                         1
# AVIAT AIRCRAFT INC                  1
# SOCATA                              1
# GULFSTREAM AEROSPACE CORP           1
# DASSAULT                            1
# MARZ BARRY                          1
# Name: mfr_name, dtype: int64

# %%
aircraft_info[aircraft_info['mfr_name']=='AIRBUS']
# Out:
#        N-Number AircraftMFRModelCode Year Mfr TypeAcft mfr_name model_name  \
# 36551    N631NK              3940004     2014        5   AIRBUS   A320-232
# 36552    N678AW              3940004     2005        5   AIRBUS   A320-232
# 36553    N705JB              3940004     2008        5   AIRBUS   A320-232
# 36554    N634NK              3940004     2014        5   AIRBUS   A320-232
# 36555    N597JB              3940004     2004        5   AIRBUS   A320-232
# ...         ...                  ...      ...      ...      ...        ...
# 280520   N376NW              3940010     2002        5   AIRBUS   A320-212
# 280521   N375NC              3940010     2002        5   AIRBUS   A320-212
# 285596   N378NW              3940025     2003        5   AIRBUS   A320-211
# 285598   N377NW              3940025     2003        5   AIRBUS   A320-211
# 286972   N851NW              3930374     2004        5   AIRBUS   A330-223
#
#        type num_engines num_passengers
# 36551     5           2            200
# 36552     5           2            200
# 36553     5           2            200
# 36554     5           2            200
# 36555     5           2            200
# ...     ...         ...            ...
# 280520    5           2            182
# 280521    5           2            182
# 285596    5           2            182
# 285598    5           2            182
# 286972    5           2            379
#
# [974 rows x 9 columns]

# %%
aircraft_info[aircraft_info['mfr_name']=='BOEING']['model_name'].unique()
# Out:
# array(['737-7H4', '737-3Y0', '767-424ER', '737-890', '767-324', '737-790',
#        '777-232', '737-3H4', '737-932ER', '737-924ER', '757-231',
#        '737-7BD', '757-224', '737-76N', '737-7Q8', '737-3Q8', '737-8H4',
#        '757-222', '737-7CT', '767-33A', '757-232', '737-724', 'MD-90-30',
#        '737-705', '757-26D', '737-824', '757-2B7', '717-200', '787-8',
#        '737-8FH', '767-323', '737-76Q', '737-73V', '787-9', '737-752',
#        '757-251', '777-222', '757-351', '737-832', '737-79P', '757-2Q8',
#        '757-28A', '737-71Q', '737-990ER', '737-3T5', '767-322', '737-990',
#        '767-332', '737-732', '747-422', '737-7L9', '777-224', '737-7V3',
#        '757-223', '737-5H4', '767-201', '737-3L9', '757-23N', '737-700',
#        '757-212', '737-4Q8', '737-301', '727-223', '767-2B7', '757-33N',
#        '737-3A4', '757-2S7', '757-2G7', '747-451', '767-3P6', '767-432ER',
#        '737-490', '737-3TO', '737-7AD', '737-924', '737-4S3', '737-3K2',
#        '767-3CB', '737-3G7', '757-324', '777-232LR', '737-7K9', '737-7BX'],
#       dtype=object)

# %%
aircraft_info[aircraft_info['model_name']=='A320-232']
# Out:
#        N-Number AircraftMFRModelCode Year Mfr TypeAcft mfr_name model_name  \
# 36551    N631NK              3940004     2014        5   AIRBUS   A320-232
# 36552    N678AW              3940004     2005        5   AIRBUS   A320-232
# 36553    N705JB              3940004     2008        5   AIRBUS   A320-232
# 36554    N634NK              3940004     2014        5   AIRBUS   A320-232
# 36555    N597JB              3940004     2004        5   AIRBUS   A320-232
# ...         ...                  ...      ...      ...      ...        ...
# 119962   N469UA              3930326     2001        5   AIRBUS   A320-232
# 119963   N519JB              3930326     2001        5   AIRBUS   A320-232
# 119968   N401UA              3930326     1993        5   AIRBUS   A320-232
# 119969   N442UA              3930326     1998        5   AIRBUS   A320-232
# 119970   N432UA              3930326     1996        5   AIRBUS   A320-232
#
#        type num_engines num_passengers
# 36551     5           2            200
# 36552     5           2            200
# 36553     5           2            200
# 36554     5           2            200
# 36555     5           2            200
# ...     ...         ...            ...
# 119962    5           2            200
# 119963    5           2            200
# 119968    5           2            200
# 119969    5           2            200
# 119970    5           2            200
#
# [297 rows x 9 columns]

# %%
flights.hist()
# Out:
# array([[<AxesSubplot:title={'center':'FLIGHT_NUMBER'}>,
#         <AxesSubplot:title={'center':'DEPARTURE_TIME'}>,
#         <AxesSubplot:title={'center':'DEPARTURE_DELAY'}>,
#         <AxesSubplot:title={'center':'TAXI_OUT'}>],
#        [<AxesSubplot:title={'center':'WHEELS_OFF'}>,
#         <AxesSubplot:title={'center':'SCHEDULED_TIME'}>,
#         <AxesSubplot:title={'center':'ELAPSED_TIME'}>,
#         <AxesSubplot:title={'center':'AIR_TIME'}>],
#        [<AxesSubplot:title={'center':'DISTANCE'}>,
#         <AxesSubplot:title={'center':'WHEELS_ON'}>,
#         <AxesSubplot:title={'center':'TAXI_IN'}>,
#         <AxesSubplot:title={'center':'ARRIVAL_TIME'}>],
#        [<AxesSubplot:title={'center':'ARRIVAL_DELAY'}>,
#         <AxesSubplot:title={'center':'DIVERTED'}>,
#         <AxesSubplot:title={'center':'CANCELLED'}>,
#         <AxesSubplot:title={'center':'AIR_SYSTEM_DELAY'}>],
#        [<AxesSubplot:title={'center':'SECURITY_DELAY'}>,
#         <AxesSubplot:title={'center':'AIRLINE_DELAY'}>,
#         <AxesSubplot:title={'center':'LATE_AIRCRAFT_DELAY'}>,
#         <AxesSubplot:title={'center':'WEATHER_DELAY'}>]], dtype=object)
